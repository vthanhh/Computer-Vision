# %% [markdown]
# <center>
#     <img src='images/logo.png' width='400px'>
#     <h1>MÔN HỌC: THỊ GIÁC MÁY TÍNH (7080518)</h1>
#     <h2> Chương 1: Tổng quan về thị giác máy tính - Phần 2 </h2>
# </center>
#
# ---
# **NỘI DUNG BÀI HỌC:**
#
# 1. Thu thập và biểu diễn ảnh trong máy tính
# 2. Một số định dạng ảnh cơ bản
# 3. Không gian màu và cách chuyển đổi với OpenCV
# 4. Bài tập thực hành
# ---
# * Họ và Tên: Phạm Văn Thanh
# * MSSV: 1921050540
# * Lớp: DCCTKH64B

# %% [markdown]
# ## THỰC HÀNH 1.4:
# ---
# Yêu cầu:
# 1. Sinh viên đọc ảnh images/Thuchanh_4.jpg dạng ảnh xám và hiển thị ảnh
# 2. Cho biết kích thước của ảnh và hiển thị ma trận pixel điểm ảnh
# 3. Tách lấy ảnh một chú mèo bất kỳ mà bạn thích và ghi ảnh đó vào thư mục images/Saves đặt tên file MSV_mycat.png

# %%
#Import các thư viện sử dụng
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
#{SINH VIÊN VIẾT CODE VÀO ĐÂY}
#a) Đọc ảnh với thư viện cv2 và hiển thị ảnh
path_14 = 'images/Thuchanh_4.jpg'
img_gray = cv2.imread(path_14,0)
print(img_gray)

plt.imshow(img_gray,cmap='gray')
plt.grid() # soc
plt.show()
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
#b) Cho biết kích thước của ảnh
img_gray.shape
# Out:
# (220, 612)

# %%
#ma trận dữ liệu điểm ảnh
img_gray
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
#c) Tách lấy một chú mèo và lưu lại
img14 = img_gray[50:200,120:180]
plt.imshow(img14,cmap='gray')
plt.show()

# %%
#Ghi ảnh:
cv2.imwrite('images/Saves/1921050540_mycat.png',img14)
# Out:
# True

# %% [markdown]
# ## THỰC HÀNH 1.5:
# ---
# Yêu cầu:
# 1. Sinh viên đọc ảnh màu images/Thuchanh_5.jpg
# 2. Cho biết chiều cao, chiều rộng và số pixel điểm ảnh.
# 3. Tách thành các kênh màu B-G-R tương ứng và hiển thị như yêu cầu trong slide
# 4. Ghi từng kênh màu thành các ảnh riêng vào thư mục images/Saves đặt tên như sau: MSV_blue.jpg; MSV_green.jpg; MSV_red.jpg

# %%
#{SINH VIÊN VIẾT CODE VÀO ĐÂY}
#Import các thư viện sử dụng
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
path_15 = 'images/Thuchanh_5.jpg'
#1. Đọc ảnh với chế độ mặc định: 
img_15 = cv2.imread(path_15,1)
img_RGB = cv2.cvtColor(img_15,cv2.COLOR_BGR2RGB)
plt.imshow(img_RGB)
plt.show()

# %%
#2. Hiển thị thông tin ảnh:
print('Kích thước ảnh:',img_15.shape)
print('Số pixel đểm ảnh :',img_15.size)
# Out:
# Kích thước ảnh: (402, 728, 3)
# Số pixel đểm ảnh : 877968

# %%
#3. Tách các kênh màu B, G, R từ ảnh màu
#Tách các kênh màu B, G, R từ ảnh màu
b_channel = None
g_channel = None
r_channel = None

#LẤY DỮ LIỆU CÁC KÊNH MÀU: BGR B=0 | G=1 | R=2
b_channel = img_15.copy()
b_channel[:, :, [1,2]] = 0 #chuyen doi kenh GR = 0 giu lai B

g_channel = img_15.copy() #chuyen doi kenh BR = 0 giu lai G
g_channel[:, :, [0, 2]] = 0

r_channel = img_15.copy()
r_channel[:, :, [0, 1]] = 0

# %%
#Hiển thị ảnh gốc và các kênh màu RGB với Matplotlib
plt.figure(figsize=(15,5))
plt.subplot(1, 4, 1)
plt.imshow(img_RGB)
plt.title('Ảnh RGB')

plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(b_channel, cv2.COLOR_BGR2RGB))
plt.title('Blue Channel')

plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(g_channel, cv2.COLOR_BGR2RGB))
plt.title('Green Channel')

plt.subplot(1, 4, 4)
plt.imshow(cv2.cvtColor(r_channel, cv2.COLOR_BGR2RGB))
plt.title('Red Channel')
plt.show()

# %%
#4.Ghi ảnh các kênh màu
#Blue
cv2.imwrite('images/Saves/1921050540_blue.jpg',b_channel)
#Green
cv2.imwrite('images/Saves/1921050540_green.jpg',g_channel)
#Red
cv2.imwrite('images/Saves/1921050540_red.jpg',r_channel)
# Out:
# True

# %% [markdown]
# # THỰC HÀNH 1.6:
# ---
# Yêu cầu: Sinh viên tìm hiểu một số hệ màu cơ bản:
# 1. Hệ màu HSV
# 2. Hệ màu CMYK

# %% [markdown]
# 1. Hệ màu HSV:
# * Không gian màu HSV (còn gọi là HSB) là một cách tự nhiên hơn để mô tả màu sắc, dựa trên 3 số liệu: H:(Hue) Vùng màu, S: (Saturation) Độ bão hòa màu, B (hay V): (Bright hay Value) Độ sáng.
# * Ứng dụng điển hình nhất của HSV là trong việc lọc màu hay tiến xa hơn là việc nhận dạng, tracking v..v.
# * Không gian màu này mô tả màu sắc (màu sắc hoặc màu) về độ bóng (độ bão hòa hoặc lượng màu xám) và giá trị độ sáng của chúng.

# %% [markdown]
# 2.Hệ màu CMYK:
#
# * CMYK là từ viết tắt tiếng Anh của cơ chế hệ màu trừ, thường được sử dụng trong in ấn. Nó bao gồm các màu sau:
# C = Cyan (xanh),
#  M = Magenta (hồng),
#  Y = Yellow (vàng),
#  K = Black (Đen) (sở dĩ dùng từ K để chỉ màu đen vì ký tự B đã được dùng để chỉ màu Blue, ngoài ra K còn có nghĩa là Key, mang ý chỉ cái gì đó là chủ yếu, là then chốt).
# * Nguyên lý làm việc chính của hệ CMYK là hấp thụ ánh sáng. Màu mà ta nhìn thấy là từ phần của ánh sáng không bị hấp thụ, hay nói cách khác, chúng hoạt động trên cơ chế những vật không tự phát ra ánh sáng mà chỉ phản xạ ánh sáng từ các nguồn khác chiếu tới. Do đó thay vì thêm độ sáng để có những màu sắc khác nhau, CMYK sẽ loại trừ ánh sáng đi từ ánh sáng gốc là màu trắng để tạo ra các màu sắc khác. 3 màu Cyan, Magenta và Yellow khi kết hợp sẽ tạo ra một màu đen.
# * Màu CMYK thường được sử dụng khi thiết kế phục vụ cho mục đích in ấn các thiết kế như poster, brochure, name card, catalogue, sách hoặc tạp chí,…
